# %% [markdown]
# #### 8. 모듈과 패키지

# %%
# 문제 8-1: 수학 연산을 위한 모듈을 만들고 이를 사용

import math_operations as mo

print(f'원의 넓이: {mo.get_circle_area(5):.2f}')
print(f'직사각형 넓이: {mo.get_rectangle_area(10, 5)}')
print(f'팩토리얼 5! = {mo.get_factorial(5)}')
print(f'최대공약수(48, 18) = {mo.get_gcd(48, 18)}')
# Out:
# 원의 넓이: 78.54
# 직사각형 넓이: 50
# 팩토리얼 5! = 120
# 최대공약수(48, 18) = 6

# %%
# 문제 8-2: datetime과 random 모듈을 사용하여 임의의 날짜와 숫자를 생성

from datetime import datetime
import random

time = datetime.now()
print(f'현재 날짜와 시간: {time}')
print(f'포맷된 날짜: {time:%Y년 %m월 %d일 %A}')

print(f'임의의 숫자: {random.randint(1, 10)}')
print(f'임의의 실수: {random.uniform(1, 10):.2f}')

fruits = ['사과', '바나나', '딸기', '포도', '오렌지']
print(f'임의의 리스트 요소: {random.choice(fruits)}')
random.shuffle(fruits)
print(f'섞인 리스트: {fruits}')
# Out:
# 현재 날짜와 시간: 2026-02-21 00:17:20.619164
# 포맷된 날짜: 2026년 02월 21일 Saturday
# 임의의 숫자: 2
# 임의의 실수: 7.86
# 임의의 리스트 요소: 오렌지
# 섞인 리스트: ['사과', '오렌지', '딸기', '포도', '바나나']

# %%
# 문제 8-3: os와 sys 모듈을 사용해서 시스템 정보를 출력하고 파일 경로를 다루는 프로그램

import os
import sys

print(f"현재 작업 디렉토리: {os.getcwd()}")
print(f"Python 버전: {sys.version}")
print(f"운영체제: {os.name}")

path_env = os.environ.get('PATH', '')
print(f"환경 변수 PATH 일부: {path_env[:50]}...")

file_path = "/Users/username/documents/report.txt"
directory, filename = os.path.split(file_path)
name, extension = os.path.splitext(filename)

print("\n파일 경로 정보:")
print(f"- 디렉토리: {directory}")
print(f"- 파일명: {filename}")
print(f"- 확장자: {extension}")

print(f"파일 존재 여부: {os.path.exists(file_path)}")
# Out:
# 현재 작업 디렉토리: c:\3.Python\Python_WebScraping_Analysis\연습문제_파이썬기본
# Python 버전: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# 운영체제: nt
# 환경 변수 PATH 일부: c:\Users\user\anaconda3;C:\Users\user\anaconda3;C:...
#
# 파일 경로 정보:
# - 디렉토리: /Users/username/documents
# - 파일명: report.txt
# - 확장자: .txt
# 파일 존재 여부: False
