# %% [markdown]
# #### 2. 문자열 처리하기

# %%
# 문제 2-1: 이름과 나이로 자기소개 문장 출력

name = input("이름을 입력하세요: ")
age = int(input("나이를 입력하세요: "))

print(f"안녕하세요! 제 이름은 {name}이고, 나이는 {age}살입니다.")
# Out:
# 안녕하세요! 제 이름은 김철수이고, 나이는 25살입니다.

# %%
# 문제 2-2: 대문자, 소문자 변환

text = input("문자열을 입력하세요: ")

print(f'대문자: {text.upper()}')
print(f'소문자: {text.lower()}')
print(f'문자열 길이: {len(text)}')
# Out:
# 대문자: HELLO WORLD
# 소문자: hello world
# 문자열 길이: 11

# %%
# 문제 2-3: 이메일 주소 분리

email = input("이메일 주소를 입력하세요: ")
part = email.split('@')

user = part[0]
domain = part[1]

print(f'사용자명: {user}')
print(f'도메인: {domain}')
# Out:
# 사용자명: user
# 도메인: naver.com

# %%
# 문제 2-4: 문장 단어의 개수 세기

sentence = input("문장을 입력하세요: ")
word = sentence.split()
new = " ".join(word)

print(f'공백 제거: {new}')
print(f'단어 개수: {len(word)}개')
# Out:
# 공백 제거: Python is great
# 단어 개수: 3개

# %%
# 문장 2-5: 문자가 몇번 나타나는지 세기

txt = input("문자열을 입력하세요: ")
counter = input("찾을 문자를 입력하세요: ")

print(f"문자 '{counter}'이 {txt.count(counter)}번 나타납니다.")
# Out:
# 문자 'm'이 2번 나타납니다.
