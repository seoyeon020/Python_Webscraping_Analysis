# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-libmamba-solver, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, PyGithub, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.13.5
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve, typing-extensions
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.5
# bs4 버전 = 4.13.5

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
# url = 'https://news.naver.com/section/105'

# dict 타입으로 요청 파라미터 설정 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보 (사람처럼 보이게 하기 위함)
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)
print(res.status_code)
print(res.ok)
print(type(res))
# print(res.text)
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
# BeautifulSoup 객체 생성  
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']"))) # <a> 태그 개수 
    # CSS 선택자를 사용해서 a tag 목록 가져오기
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
    print(type(a_tags), type(a_tags[0])) # [Tag, Tag]
    # <a> 태그 리스트 순회하기 
    for a_tag in a_tags :
        title = a_tag.text.strip()
        link = a_tag['href']
        print(title, link)
else:
    # 응답(response)이 Error 이면 status code 출력
    print(f'Error Code = {res.status_code}')

# print(soup.select("div.sa_text a[href*='mnews/article']"))
# Out:
# https://news.naver.com/section/105
# 200
# True
# <class 'requests.models.Response'>
# 88
# <class 'bs4.element.ResultSet'> <class 'bs4.element.Tag'>
# LGU+, 작년 무선 가입자 3천만 돌파...서비스매출 4.1% 증가 https://n.news.naver.com/mnews/article/092/0002409310
#  https://n.news.naver.com/mnews/article/comment/092/0002409310
# 구글, ‘고정밀 지도 반출’ 보완 서류 제출 https://n.news.naver.com/mnews/article/014/0005474401
#  https://n.news.naver.com/mnews/article/comment/014/0005474401
# 휴네시온, 작년 매출 377억·영업익 48억…사상 최대 실적 https://n.news.naver.com/mnews/article/003/0013752851
#  https://n.news.naver.com/mnews/article/comment/003/0013752851
# 넷마블, 2025년 역대 최대 매출…"신작 통해 올해 도약 전환점 마련" https://n.news.naver.com/mnews/article/092/0002409471
#  https://n.news.naver.com/mnews/article/comment/092/0002409471
# 유명인 네이버 지식인 답변 '강제 노출'에 발칵[인터넷 와글와글] https://n.news.naver.com/mnews/article/057/0001934032
#  https://n.news.naver.com/mnews/article/comment/057/0001934032
# 네이버 “커머스 최우선 과제는 배송 경쟁력 강화... N배송 적용 범위 3년 내 50%까지 확대”[컨콜] https://n.news.naver.com/mnews/article/366/0001140945
#  https://n.news.naver.com/mnews/article/comment/366/0001140945
# 네이버 '역대 최고 실적' 영업익 11.6% 증가…커머스 성장세 뚜렷 [종합] https://n.news.naver.com/mnews/article/015/0005247716
#  https://n.news.naver.com/mnews/article/comment/015/0005247716
# 온열기‧저주파자극기‧전동식모유착유기...인기 의료기기 문제없나 https://n.news.naver.com/mnews/article/092/0002409518
#  https://n.news.naver.com/mnews/article/comment/092/0002409518
# 美 외교·안보 고문 "쿠팡 규제, SKT 사고 때 보다 더 가혹" https://n.news.naver.com/mnews/article/092/0002409533
#  https://n.news.naver.com/mnews/article/comment/092/0002409533
# 비중국 전기차 배터리 26% 성장에도… 한국 3사 점유율 36%로 후퇴 [배터리레이다] https://n.news.naver.com/mnews/article/138/0002217337
#  https://n.news.naver.com/mnews/article/comment/138/0002217337
# "국가대표 AI 탈락, 네이버 기술력 방증 아냐"[컨콜] https://n.news.naver.com/mnews/article/018/0006214555
#  https://n.news.naver.com/mnews/article/comment/018/0006214555
_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section_name):  #print_new(103,'생활/문화') 
    sid = section_dict.get(section_name,'정치')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')
    req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
    }
    res = requests.get(url, headers=req_header)
    if res.ok:
        soup = BeautifulSoup(res.text, 'html.parser')
        # CSS 선택자를 사용해서 a tag 목록 가져오기
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
        print(type(a_tags), type(a_tags[0])) # [Tag, Tag]
        # <a> 태그 리스트 순회하기 
        for a_tag in a_tags :
            title = a_tag.text.strip()
            link = a_tag['href']
            print(title, link)
    else:
        # 응답(response)이 Error 이면 status code 출력
        print(f'Error Code = {res.status_code}')

# %%
print_news('경제')
# Out:
# 경제 뉴스 https://news.naver.com/section/101
# <class 'bs4.element.ResultSet'> <class 'bs4.element.Tag'>
# 삼전·기아 하한가라니…프리마켓 ‘플래시 크래시’ 해프닝 https://n.news.naver.com/mnews/article/119/0003056775
#  https://n.news.naver.com/mnews/article/comment/119/0003056775
# 모든 사업장에 퇴직연금 도입 의무화된다…기금형 도입도 합의 https://n.news.naver.com/mnews/article/009/0005633389
#  https://n.news.naver.com/mnews/article/comment/009/0005633389
# 비트코인 폭락, 스트래티지 17%-마라 19%-코인베이스 13%↓(종합) https://n.news.naver.com/mnews/article/421/0008757287
#  https://n.news.naver.com/mnews/article/comment/421/0008757287
# 정부, 30억달러 외평채 발행…대외 불확실성 속 외화 조달 https://n.news.naver.com/mnews/article/079/0004113138
#  https://n.news.naver.com/mnews/article/comment/079/0004113138
# [속보] 쿠팡 “16만5000여 계정 개인정보 유출 추가 확인” https://n.news.naver.com/mnews/article/005/0001830532
#  https://n.news.naver.com/mnews/article/comment/005/0001830532
# 현대차 팰리세이드, 미 언론 ‘최고의 차’ 2관왕 https://n.news.naver.com/mnews/article/005/0001830686
#  https://n.news.naver.com/mnews/article/comment/005/0001830686
# 일주일새 '매도→매수→매도' 사이드카…롤러코스터 탄 코스피 https://n.news.naver.com/mnews/article/008/0005314990
#  https://n.news.naver.com/mnews/article/comment/008/0005314990
# 대통령 자리 앉을뻔한 정의선…"야망 있으시네", 정면의 이재용도 '폭소'[영상] https://n.news.naver.com/mnews/article/421/0008757298
#  https://n.news.naver.com/mnews/article/comment/421/0008757298
# 코웨이, 2025년 연간 영업익 8787억원…전년비 10.5% 증가 https://n.news.naver.com/mnews/article/119/0003056847
#  https://n.news.naver.com/mnews/article/comment/119/0003056847
# KAI-한화에어로, 미래사업 개발·수출 위해 공동 전선 구축 https://n.news.naver.com/mnews/article/277/0005717998
#  https://n.news.naver.com/mnews/article/comment/277/0005717998
# 셀트리온 "스토보클로, 美 3대 PBM CVS 처방집 등재…시장 선점" https://n.news.naver.com/mnews/article/008/0005315061
#  https://n.news.naver.com/mnews/article/comment/008/0005315061
# 셀트리온 “골질환 치료제 ‘스토보클로’, 美 3대 처방집 ‘CVS 케어마크’ 등재” https://n.news.naver.com/mnews/article/366/0001140983
#  https://n.news.naver.com/mnews/article/comment/366/0001140983

    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)
    # binary 응답 데이터 가져오기
    img_data = res.content
    # print(img_data)
    # url에서 파일명만 추출하기
    file_name = os.path.basename(img_url)
    print(file_name)
    # binday data를 file에 write하기
    with open(file_name,'wb') as file:
        print(f'Writing to {file_name}({len(img_data):,} bytes)')
        file.write(img_data)
# Out:
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=thu'

req_header = {
    'referer': webtoon_url,
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

res = requests.get(webtoon_url, headers=req_header)
if res.ok:
    # .jpg 파일명을 추출해서 list에 저장하기
     # img_url_list = [] #list()
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src*='IMAG01']")))
    img_tags = soup.select("img[src*='IMAG01']")
    #for img_tag in img_tags:
        #img_url = img_tag['src']
        #img_url_list.append(img_url)

    img_url_list2 = [img_tag['src'] for img_tag in img_tags]
    print(img_url_list2[:2])

    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)
    
    for img_url in img_url_list2:
        # requests 의 get(url, headers) 함수 호출하기 
        res = requests.get(img_url, headers=req_header)
        # binary 응답 데이터 가져오기
        img_data = res.content
        # print(img_data)
        # url에서 파일명만 추출하기
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        # file_name = os.path.basename(img_url)
        # print(file_name)
        # binday data를 file에 write하기
        with open(file_path,'wb') as file:
            print(f'Writing to {file_path}({len(img_data):,} bytes)')
            file.write(img_data)

else:
    print(f'Error Code = {res.status_code}')
# Out:
# 13
# ['https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg']
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_4.jpg(164,871 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_5.jpg(132,142 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_6.jpg(131,414 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_7.jpg(116,752 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_8.jpg(143,277 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_9.jpg(130,356 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_10.jpg(129,764 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_11.jpg(111,785 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_12.jpg(86,540 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_13.jpg(7,315 bytes)

# %% [markdown]
# #### 리팩터링 된 코드

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=3&week=tue'
req_header = {'referer': url}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성 (sub 디렉터리도 생성)
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
